# %%
import pandas as pd
data = pd.read_csv(r'data/supply_chain_data.csv')
data.columns
# Out:
# Index(['Product type', 'SKU', 'Price', 'Availability',
#        'Number of products sold', 'Revenue generated', 'Customer demographics',
#        'Stock levels', 'Lead times', 'Order quantities', 'Shipping times',
#        'Shipping carriers', 'Shipping costs', 'Supplier name', 'Location',
#        'Lead time', 'Production volumes', 'Manufacturing lead time',
#        'Manufacturing costs', 'Inspection results', 'Defect rates',
#        'Transportation modes', 'Routes', 'Costs'],
#       dtype='object')

# %%
data['Location'][1]
# Out:
# 'Mumbai'

# %%
data.iloc[10]
# Out:
# Product type                  skincare
# SKU                              SKU10
# Price                        15.707796
# Availability                        11
# Number of products sold            996
# Revenue generated          2330.965802
# Customer demographics       Non-binary
# Stock levels                        51
# Lead times                          13
# Order quantities                    80
# Shipping times                       2
# Shipping carriers            Carrier C
# Shipping costs                8.673211
# Supplier name               Supplier 5
# Location                       Kolkata
# Lead time                           18
# Production volumes                 830
# Manufacturing lead time              5
# Manufacturing costs          96.527353
# Inspection results                Pass
# Defect rates                  1.727314
# Transportation modes              Road
# Routes                         Route B
# Costs                       806.103178
# ...

# %%
data.iloc[-100]
# Out:
# Product type                  haircare
# SKU                               SKU0
# Price                        69.808006
# Availability                        55
# Number of products sold            802
# Revenue generated          8661.996792
# Customer demographics       Non-binary
# Stock levels                        58
# Lead times                           7
# Order quantities                    96
# Shipping times                       4
# Shipping carriers            Carrier B
# Shipping costs                2.956572
# Supplier name               Supplier 3
# Location                        Mumbai
# Lead time                           29
# Production volumes                 215
# Manufacturing lead time             29
# Manufacturing costs          46.279879
# Inspection results             Pending
# Defect rates                   0.22641
# Transportation modes              Road
# Routes                         Route B
# Costs                       187.752075
# ...

# %% [markdown]
# iloc uses the Python stdlib indexing scheme, where the first element of the range is included and the last one excluded. So 0:10 will select entries 0,...,9. loc, meanwhile, indexes inclusively. So 0:10 will select entries 0,...,10

# %% [markdown]
# MANIPILATING THE INDEX

# %%
data.loc[(data['Location'] == 'Mumbai') & (data['Shipping costs'] >= 2)]
# Out:
#    Product type    SKU      Price  Availability  Number of products sold  \
# 0      haircare   SKU0  69.808006            55                      802
# 1      skincare   SKU1  14.843523            95                      736
# 2      haircare   SKU2  11.319683            34                        8
# 8     cosmetics   SKU8  68.717597            78                      150
# 27    cosmetics  SKU27  92.557361            42                      352
# 28    cosmetics  SKU28   2.397275            12                      394
# 38    cosmetics  SKU38  52.075931            75                      705
# 43     haircare  SKU43  11.743272             6                      598
# 48     haircare  SKU48  76.035544            28                       29
# 52     skincare  SKU52  98.031830             1                      820
# 60     skincare  SKU60  17.028028            16                      380
# 62    cosmetics  SKU62  72.796354            89                      270
# ...

# %%
data.loc[(data['Location'] == 'Delhi') | (data['Shipping costs'] >= 2)]
# Out:
#    Product type    SKU      Price  Availability  Number of products sold  \
# 0      haircare   SKU0  69.808006            55                      802
# 1      skincare   SKU1  14.843523            95                      736
# 2      haircare   SKU2  11.319683            34                        8
# 4      skincare   SKU4   4.805496            26                      871
# 5      haircare   SKU5   1.699976            87                      147
# ..          ...    ...        ...           ...                      ...
# 93     haircare  SKU93  69.290831            88                      114
# 94    cosmetics  SKU94   3.037689            97                      987
# 95     haircare  SKU95  77.903927            65                      672
# 96    cosmetics  SKU96  24.423131            29                      324
# 97     haircare  SKU97   3.526111            56                       62
#
#     Revenue generated Customer demographics  Stock levels  Lead times  \
# ...

# %%
data.loc[data['Location'].isin(['Mumbai', 'Bangalore'])]
# Out:
#    Product type    SKU      Price  Availability  Number of products sold  \
# 0      haircare   SKU0  69.808006            55                      802
# 1      skincare   SKU1  14.843523            95                      736
# 2      haircare   SKU2  11.319683            34                        8
# 5      haircare   SKU5   1.699976            87                      147
# 7     cosmetics   SKU7  42.958384            59                      426
# 8     cosmetics   SKU8  68.717597            78                      150
# 13     skincare  SKU13  16.160393             5                      249
# 15     skincare  SKU15  36.989245            94                      469
# 16     skincare  SKU16   7.547172            74                      280
# 24     haircare  SKU24   4.156308            32                      209
# 26     haircare  SKU26  97.446947             9                      353
# 27    cosmetics  SKU27  92.557361            42                      352
# ...

# %%
data.loc[data['Routes'].notnull()]
# Out:
#    Product type    SKU      Price  Availability  Number of products sold  \
# 0      haircare   SKU0  69.808006            55                      802
# 1      skincare   SKU1  14.843523            95                      736
# 2      haircare   SKU2  11.319683            34                        8
# 3      skincare   SKU3  61.163343            68                       83
# 4      skincare   SKU4   4.805496            26                      871
# ..          ...    ...        ...           ...                      ...
# 95     haircare  SKU95  77.903927            65                      672
# 96    cosmetics  SKU96  24.423131            29                      324
# 97     haircare  SKU97   3.526111            56                       62
# 98     skincare  SKU98  19.754605            43                      913
# 99     haircare  SKU99  68.517833            17                      627
#
#     Revenue generated Customer demographics  Stock levels  Lead times  \
# ...

# %% [markdown]
# SUMMARY FUNCTIONS AND MAPPING

# %%
data.describe()
# Out:
#             Price  Availability  Number of products sold  Revenue generated  \
# count  100.000000    100.000000               100.000000         100.000000
# mean    49.462461     48.400000               460.990000        5776.048187
# std     31.168193     30.743317               303.780074        2732.841744
# min      1.699976      1.000000                 8.000000        1061.618523
# 25%     19.597823     22.750000               184.250000        2812.847151
# 50%     51.239831     43.500000               392.500000        6006.352023
# 75%     77.198228     75.000000               704.250000        8253.976921
# max     99.171329    100.000000               996.000000        9866.465458
#
#        Stock levels  Lead times  Order quantities  Shipping times  \
# count    100.000000  100.000000        100.000000      100.000000
# mean      47.770000   15.960000         49.220000        5.750000
# std       31.369372    8.785801         26.784429        2.724283
# ...

# %%
data.Price.mean()
# Out:
# np.float64(49.462461344643685)

# %%
data.Location.unique()
# Out:
# array(['Mumbai', 'Kolkata', 'Delhi', 'Bangalore', 'Chennai'], dtype=object)

# %%
data.Location.value_counts()
# Out:
# Location
# Kolkata      25
# Mumbai       22
# Chennai      20
# Bangalore    18
# Delhi        15
# Name: count, dtype: int64

# %%
data['Customer demographics'].value_counts()
# Out:
# Customer demographics
# Unknown       31
# Female        25
# Non-binary    23
# Male          21
# Name: count, dtype: int64

# %% [markdown]
# A map is a term, borrowed from mathematics, for a function that takes one set of values and "maps" them to another set of values

# %% [markdown]
# In data science we often have a need for creating new representations from existing data, or for transforming data from the format it is in now to the format that we want it to be in later

# %%
data_Revenue_generated_mean = data['Revenue generated'].mean()


data['Revenue generated'].map(lambda p: p - data_Revenue_generated_mean)

#Your code calculates the mean revenue and then applies a lambda function to subtract this mean from each value in the 'Revenue generated' column.
# Out:
# 0     2885.948605
# 1     1684.851878
# 2     3801.701438
# 3     1990.788238
# 4    -3089.543036
#          ...
# 95    1610.315757
# 96    1922.376578
# 97   -1405.131607
# 98    2749.904372
# 99    3409.137642
# Name: Revenue generated, Length: 100, dtype: float64

# %% [markdown]
# GROUPING AND SORTING

# %%
data.groupby('Customer demographics')['Customer demographics'].count()
# Out:
# Customer demographics
# Female        25
# Male          21
# Non-binary    23
# Unknown       31
# Name: Customer demographics, dtype: int64

# %% [markdown]
# Getting the least(minimum) number of products sold

# %%
data.groupby("Product type")['Number of products sold'].min()
# Out:
# Product type
# cosmetics    25
# haircare      8
# skincare     65
# Name: Number of products sold, dtype: int64

# %%
data.groupby("Product type")['Number of products sold'].max()
# Out:
# Product type
# cosmetics    987
# haircare     946
# skincare     996
# Name: Number of products sold, dtype: int64

# %% [markdown]
# where are the most products appearing in the most

# %%
data.groupby('Product type')['Location'].max()
# Out:
# Product type
# cosmetics    Mumbai
# haircare     Mumbai
# skincare     Mumbai
# Name: Location, dtype: object

# %%
data.groupby('Location').apply(lambda df: df.SKU.iloc[0])

#The apply() function operates on each group (i.e., each subset of data that belongs to a unique Location).

#The lambda function selects the first SKU (df.SKU.iloc[0]) from each group.
# Out:
# C:\Users\windows 10\AppData\Local\Temp\ipykernel_8928\4238272393.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   data.groupby('Location').apply(lambda df: df.SKU.iloc[0])
# Location
# Bangalore    SKU5
# Chennai      SKU9
# Delhi        SKU4
# Kolkata      SKU3
# Mumbai       SKU0
# dtype: object

# %% [markdown]
# SORTING

# %% [markdown]
# Number of products sold in each country

# %%
data.groupby('Location')['Shipping costs'].mean().sort_by('Location',ascending == False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8928\52200464.py in ?()
# ----> 1 data.groupby('Location')['Shipping costs'].mean().sort_by('Location',ascending == False)
#
# c:\Users\windows 10\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'sort_by'
